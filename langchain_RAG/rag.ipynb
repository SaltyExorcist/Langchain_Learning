# %%
from youtube_transcript_api import YouTubeTranscriptApi, TranscriptsDisabled
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_huggingface import HuggingFacePipeline,ChatHuggingFace
from langchain_community.vectorstores import FAISS
from langchain_core.prompts import PromptTemplate

# %% [markdown]
# ## Step 1a - Indexing (Document Ingestion

# %%
video_id = "bgzP3yn1kNE" # only the ID, not full URL
try:
    # If you don’t care which language, this returns the “best” one
    transcript_list = YouTubeTranscriptApi.get_transcript(video_id, languages=["en"])

    # Flatten it to plain text
    transcript = " ".join(chunk["text"] for chunk in transcript_list)
    print(transcript)

except TranscriptsDisabled:
    print("No captions available for this video.")
# Out:
# it is truly wonderful to see you where are we we're in central London we've come to Mayfair now we are going to a very very special Indian restaurant I went to verish Swami now it's got one Michelin star and loads of you turned around and said Gary there's a better one I was thinking wow there can't be a better one is there gave me a recommendation what is it Jim Cara now it specializes in Northern Indian food and it hasn't got one it's got two to michelan Stars so it's got to be seriously up there you asked me to go here quite a while ago it's Tak me ages to get a booking 3 months waiting list so if you're ever interested in coming here you're going to have to be a bit patient can't wait for it as always got to be careful here let's give it a go kind it has to be very patient the road is suddenly become padilly circus not Mayfair I won't pass go and I won't collect 200 come on look at the menu outside it's certainly not for the Fain hearted I'm going to give you one simple example here oh dear me where are be game chops you know I like my lamb chops lamb chops uh 66 let's go [Music] [Music] oh my good God it is stunning in here it is truly truly stunning you walk through you're greeted at the door beautiful restaurant there a bar at the end and you come downstairs which I've come to because I want to try and get in I've got in early and I don't want to be disturbing other customers because they're coming in spending this kind of money they don't want Gary yapping away in the background but it's beautiful area down here it's got a bar as well and a private dining area all in all I'm like absolutely stunned it is beautiful truly beautiful this menu it is a tight tight menu um and you'd expect that under naster I'm going to go for the pan of py now what you do here you hollow out then you put the different sources in you put it into your mouth and hopefully it' be an explosion of flavors and that's 12250 I'm very sad very sad I'm looking down lamb shank Rogan Josh I'm get keep getting told off for having lamb okay I won't have it pressure youve put me under pressure um I'm going to go for the Goen prawn Curry that's £33 really interested to see what that looks like and their specialty here a real speciality is their chicken butter masala that's 33 with that I'm going to get a selection of Breads and uh I'm going to get a rice as well uh the Bread Basket IS250 and the rice is £7 all in all wow wow this is just levels levels above uh any Indian restaurant I ever been in my life it is truly truly stunning staff bang super attentive so yeah really interested to see what it all comes comes out like I've never ever in my life being to a two- rated michelan Star restaurant ever I have I have been to one rated but uh that's HS and ver schami but golly gosh is it going to be really pretentious this hope not you know I feel very relaxed in here so I can't see W Hell by the way I just want to show you something here as well they do do a lunch menu now this comes in a lot cheaper this is £60 and again if you take a look I'm not going to run through it all so again if you if you're thinking well I want to experience it but I don't want to actually spend huge money just take a look lunch menu yeah and it's a quite an extensive Lun Munch Munch Munch lunch Munch menu so um yeah interesting I'll see you when my starter [Music] arrives an explosion I hope so anyway pany here we go take a look here so you got chickpeas and Tamarind and various spices in there this is very simple what you do you pick one up okay first part done no problem at all then you create this is going to be it a little Hollow maybe a bit bit more than that because uh I'm going to struggle otherwise pick this up I'm very sorry about doing that fill it up that's in there now this is a bit spicy so what you do or what I'm going to do it's going to St nice and gentle so you pour that in let's not go mad let's not going mad first time put that there and then in one so it's not li ...

# %%
transcript_list
# Out:
# [{'text': 'it is truly wonderful to see you where',
#   'start': 0.56,
#   'duration': 3.799},
#  {'text': "are we we're in central London we've",
#   'start': 2.44,
#   'duration': 5.16},
#  {'text': 'come to Mayfair now we are going to a',
#   'start': 4.359,
#   'duration': 6.841},
#  {'text': 'very very special Indian restaurant I',
#   'start': 7.6,
#   'duration': 5.32},
#  {'text': "went to verish Swami now it's got one",
#   'start': 11.2,
#   'duration': 3.92},
#  {'text': 'Michelin star and loads of you turned',
#   'start': 12.92,
#   'duration': 4.48},
#  {'text': "around and said Gary there's a better",
#   'start': 15.12,
#   'duration': 4.079},
#  {'text': "one I was thinking wow there can't be a",
#   'start': 17.4,
#   'duration': 4.119},
#  {'text': 'better one is there gave me a', 'start': 19.199, 'duration': 6.24},
#  {'text': 'recommendation what is it Jim Cara now',
#   'start': 21.519,
#   'duration': 6.441},
#  {'text': 'it specializes in Northern Indian food',
#   'start': 25.439,
#   'duration': 5.041},
#  {'text': "and it hasn't got one it's got two to",
#   'start': 27.96,
#   'duration': 4.439},
#  {'text': "michelan Stars so it's got to be",
#   'start': 30.48,
#   'duration': 4.599},
#  {'text': 'seriously up there you asked me to go',
#   'start': 32.399,
#   'duration': 5.241},
#  {'text': "here quite a while ago it's Tak me ages",
#   'start': 35.079,
#   'duration': 4.8},
#  {'text': 'to get a booking 3 months waiting list',
#   'start': 37.64,
#   'duration': 3.88},
#  {'text': "so if you're ever interested in coming",
#   'start': 39.879,
#   'duration': 3.281},
#  {'text': "here you're going to have to be a bit",
#   'start': 41.52,
#   'duration': 4.559},
#  {'text': "patient can't wait for it as", 'start': 43.16, 'duration': 6.84},
#  {'text': "always got to be careful here let's give",
#   'start': 46.079,
#   'duration': 7.041},
#  {'text': 'it a go kind it has to be very patient',
#   'start': 50.0,
#   'duration': 4.76},
#  {'text': 'the road is suddenly become padilly',
#   'start': 53.12,
#   'duration': 4.759},
#  {'text': "circus not Mayfair I won't pass go and I",
#   'start': 54.76,
#   'duration': 6.2},
#  {'text': "won't collect 200", 'start': 57.879, 'duration': 5.2},
#  {'text': 'come', 'start': 60.96, 'duration': 2.119},
#  {'text': "on look at the menu outside it's",
#   'start': 63.08,
#   'duration': 3.76},
#  {'text': "certainly not for the Fain hearted I'm",
#   'start': 65.4,
#   'duration': 3.079},
#  {'text': 'going to give you one simple example',
#   'start': 66.84,
#   'duration': 4.919},
#  {'text': 'here oh dear me where are be game chops',
#   'start': 68.479,
#   'duration': 5.68},
#  {'text': 'you know I like my lamb chops lamb chops',
#   'start': 71.759,
#   'duration': 4.36},
#  {'text': 'uh', 'start': 74.159, 'duration': 6.241},
#  {'text': "66 let's go", 'start': 76.119, 'duration': 4.281},
#  {'text': '[Music]', 'start': 80.56, 'duration': 17.06},
#  {'text': '[Music]', 'start': 100.02, 'duration': 4.4},
#  {'text': 'oh my good God it is stunning in here it',
#   'start': 106.0,
#   'duration': 4.24},
#  {'text': 'is truly truly stunning you walk through',
#   'start': 108.28,
#   'duration': 3.96},
#  {'text': "you're greeted at the door beautiful",
#   'start': 110.24,
#   'duration': 3.76},
#  {'text': 'restaurant there a bar at the end and',
#   'start': 112.24,
#   'duration': 3.44},
#  {'text': "you come downstairs which I've come to",
#   'start': 114.0,
#   'duration': 3.119},
#  {'text': "because I want to try and get in I've",
#   'start': 115.68,
#   'duration': 2.84},
#  {'text': "got in early and I don't want to be",
#   'start': 117.119,
#   'duration': 3.04},
#  {'text': 'disturbing other customers because',
#   'start': 118.52,
#   'duration': 2.8},
#  {'text': "they're coming in spending this kind of",
#   'start': 120.159,
#   'duration': 2.481},
#  {'text': "money they don't want Gary yapping away",
#   'start': 121.32,
#   'duration': 3.439},
#  {'text': "in the background but it's beautiful",
#   'start': 122.64,
#   'duration': 4.159},
#  {'text': "area down here it's got a bar as well",
#   'start': 124.759,
#   'duration': 4.401},
#  {'text': "and a private dining area all in all I'm",
#   'start': 126.799,
#   'duration': 6.881},
#  {'text': 'like absolutely stunned it is beautiful',
#   'start': 129.16,
#   'duration': 8.159},
#  {'text': 'truly beautiful this menu it is a tight',
#   'start': 133.68,
#   'duration': 6.16},
#  {'text': "tight menu um and you'd expect that",
#   'start': 137.319,
#   'duration': 4.0},
#  {'text': "under naster I'm going to go for the pan",
#   'start': 139.84,
#   'duration': 4.119},
#  {'text': 'of py now what you do here you hollow',
#   'start': 141.319,
#   'duration': 4.961},
#  {'text': 'out then you put the different sources',
#   'start': 143.959,
#   'duration': 3.681},
#  {'text': 'in you put it into your mouth and',
#   'start': 146.28,
#   'duration': 3.319},
#  {'text': "hopefully it' be an explosion of flavors",
#   'start': 147.64,
#   'duration': 6.679},
#  {'text': "and that's 12250 I'm very sad very sad",
#   'start': 149.599,
#   'duration': 8.041},
#  {'text': "I'm looking down lamb shank Rogan Josh",
#   'start': 154.319,
#   'duration': 6.441},
#  {'text': "I'm get keep getting told off for having",
#   'start': 157.64,
#   'duration': 6.92},
#  {'text': "lamb okay I won't have it pressure youve",
#   'start': 160.76,
#   'duration': 5.04},
#  {'text': 'put me under', 'start': 164.56, 'duration': 3.84},
#  {'text': "pressure um I'm going to go for the Goen",
#   'start': 165.8,
#   'duration': 4.159},
#  {'text': "prawn Curry that's", 'start': 168.4, 'duration': 3.559},
#  {'text': '£33 really interested to see what that',
#   'start': 169.959,
#   'duration': 3.92},
#  {'text': 'looks like and their specialty here a',
#   'start': 171.959,
#   'duration': 5.521},
#  {'text': 'real speciality is their chicken butter',
#   'start': 173.879,
#   'duration': 6.401},
#  {'text': "masala that's 33", 'start': 177.48, 'duration': 4.0},
#  {'text': "with that I'm going to get a selection",
#   'start': 180.28,
#   'duration': 3.44},
#  {'text': "of Breads and uh I'm going to get a rice",
#   'start': 181.48,
#   'duration': 5.039},
#  {'text': 'as well uh the Bread Basket IS250 and',
#   'start': 183.72,
#   'duration': 6.879},
#  {'text': 'the rice is £7 all in all wow wow this',
#   'start': 186.519,
#   'duration': 8.8},
#  {'text': 'is just levels levels above uh any',
#   'start': 190.599,
#   'duration': 7.2},
#  {'text': 'Indian restaurant I ever been in my life',
#   'start': 195.319,
#   'duration': 3.881},
#  {'text': 'it is', 'start': 197.799, 'duration': 6.761},
#  {'text': 'truly truly stunning staff bang super',
#   'start': 199.2,
#   'duration': 8.16},
#  {'text': 'attentive so yeah really interested to',
#   'start': 204.56,
#   'duration': 4.679},
#  {'text': 'see what it all comes comes out like',
#   'start': 207.36,
#   'duration': 4.159},
#  {'text': "I've never ever in my life being to a",
#   'start': 209.239,
#   'duration': 5.441},
#  {'text': 'two- rated michelan Star restaurant ever',
#   'start': 211.519,
#   'duration': 5.761},
#  {'text': 'I have I have been to one rated but uh',
#   'start': 214.68,
#   'duration': 5.96},
#  {'text': "that's HS and ver schami", 'start': 217.28, 'duration': 5.8},
#  {'text': 'but golly gosh is it going to be really',
#   'start': 220.64,
#   'duration': 4.519},
#  {'text': 'pretentious this hope not you know I',
#   'start': 223.08,
#   'duration': 4.48},
#  {'text': "feel very relaxed in here so I can't see",
#   'start': 225.159,
#   'duration': 4.16},
#  {'text': 'W Hell by the way I just want to show',
#   'start': 227.56,
#   'duration': 3.36},
#  {'text': 'you something here as well they do do a',
#   'start': 229.319,
#   'duration': 3.241},
#  {'text': 'lunch menu now this comes in a lot',
#   'start': 230.92,
#   'duration': 4.36},
#  {'text': 'cheaper this is £60 and again if you',
#   'start': 232.56,
#   'duration': 4.12},
#  {'text': "take a look I'm not going to run through",
#   'start': 235.28,
#   'duration': 3.2},
#  {'text': "it all so again if you if you're",
#   'start': 236.68,
#   'duration': 4.0},
#  {'text': 'thinking well I want to experience it',
#   'start': 238.48,
#   'duration': 4.2},
#  {'text': "but I don't want to actually spend huge",
#   'start': 240.68,
#   'duration': 4.44},
#  {'text': 'money just take a look lunch menu yeah',
#   'start': 242.68,
#   'duration': 4.399},
#  {'text': "and it's a quite an extensive Lun Munch",
#   'start': 245.12,
#   'duration': 6.88},
#  {'text': 'Munch Munch lunch Munch menu so um yeah',
#   'start': 247.079,
#   'duration': 8.361},
#  {'text': "interesting I'll see you when my starter",
#   'start': 252.0,
#   'duration': 4.639},
#  {'text': '[Music]', 'start': 255.44, 'duration': 4.639},
#  {'text': 'arrives an explosion I hope so',
#   'start': 256.639,
#   'duration': 7.921},
#  {'text': 'anyway pany here we go take a look here',
#   'start': 260.079,
#   'duration': 7.081},
#  {'text': 'so you got chickpeas and Tamarind and',
#   'start': 264.56,
#   'duration': 5.6},
#  {'text': 'various spices in there this is very',
#   'start': 267.16,
#   'duration': 5.68},
#  {'text': 'simple what you do you pick one',
#   'start': 270.16,
#   'duration': 4.28},
#  {'text': 'up', 'start': 272.84, 'duration': 4.84},
#  {'text': 'okay first part done no problem at all',
#   'start': 274.44,
#   'duration': 7.36},
#  {'text': 'then you create this is going to be',
#   'start': 277.68,
#   'duration': 4.12},
#  {'text': 'it a little', 'start': 284.0, 'duration': 4.96},
#  {'text': 'Hollow maybe a bit bit more than that',
#   'start': 286.4,
#   'duration': 4.48},
#  {'text': "because uh I'm going to struggle",
#   'start': 288.96,
#   'duration': 5.04},
#  {'text': "otherwise pick this up I'm very sorry",
#   'start': 290.88,
#   'duration': 5.56},
#  {'text': 'about doing', 'start': 294.0, 'duration': 2.44},
#  {'text': 'that fill it up', 'start': 298.0, 'duration': 3.639},
#  {'text': "that's in there now this is a bit spicy",
#   'start': 303.32,
#   'duration': 6.28},
#  {'text': "so what you do or what I'm going to do",
#   'start': 306.8,
#   'duration': 5.08},
#  {'text': "it's going to St nice and gentle so you",
#   'start': 309.6,
#   'duration': 4.0},
#  {'text': 'pour that', 'start': 311.88, 'duration': 4.72},
#  {'text': "in let's not go mad let's not going mad",
#   'start': 313.6,
#   'duration': 4.159},
#  {'text': 'first', 'start': 316.6, 'duration': 3.76},
#  {'text': 'time put that', 'start': 317.759, 'duration': 6.601},
#  {'text': "there and then in one so it's not like a",
#   'start': 320.36,
#   'duration': 7.76},
#  {'text': 'bite in one', 'start': 324.36, 'duration': 3.76},
#  {'text': 'oh my', 'start': 335.4, 'duration': 5.079},
#  {'text': 'god bang no other word for it that was',
#   'start': 336.8,
#   'duration': 6.04},
#  {'text': 'an explosion of', 'start': 340.479, 'duration': 4.761},
#  {'text': 'flavor so you have the chickpea then you',
#   'start': 342.84,
#   'duration': 4.799},
#  {'text': 'have some spices in there but the',
#   'start': 345.24,
#   'duration': 5.36},
#  {'text': 'overriding flavor to start with is',
#   'start': 347.639,
#   'duration': 4.961},
#  {'text': "tamarind I'm getting excited I'm moving",
#   'start': 350.6,
#   'duration': 4.64},
#  {'text': 'this over then this guy comes into play',
#   'start': 352.6,
#   'duration': 4.64},
#  {'text': 'and that gives you a real', 'start': 355.24, 'duration': 4.64},
#  {'text': "kick so it's balancing the flavors so",
#   'start': 357.24,
#   'duration': 6.28},
#  {'text': 'you get this flavor first and then when',
#   'start': 359.88,
#   'duration': 6.2},
#  {'text': 'you actually having it all going around',
#   'start': 363.52,
#   'duration': 4.64},
#  {'text': "the mouth it's just suddenly a major",
#   'start': 366.08,
#   'duration': 4.839},
#  {'text': "explosion of flavors I've never I've",
#   'start': 368.16,
#   'duration': 4.92},
#  {'text': 'never experienced that before seriously',
#   'start': 370.919,
#   'duration': 4.881},
#  {'text': "I'm just I'm like forget it I've got to",
#   'start': 373.08,
#   'duration': 4.2},
#  {'text': 'go in', 'start': 375.8, 'duration': 3.64},
#  {'text': "again don't ruin this Gary just cuz",
#   'start': 377.28,
#   'duration': 4.359},
#  {'text': "you're", 'start': 379.44, 'duration': 2.199},
#  {'text': 'excited once', 'start': 381.72, 'duration': 4.52},
#  {'text': 'again sorry this going to be on repeat',
#   'start': 383.96,
#   'duration': 3.959},
#  {'text': 'for a little', 'start': 386.24, 'duration': 5.0},
#  {'text': 'bit but this time', 'start': 387.919, 'duration': 4.68},
#  {'text': 'a little bit more', 'start': 391.24, 'duration': 7.84},
#  {'text': 'heat so put you in there oh see see Gary',
#   'start': 392.599,
#   'duration': 8.921},
#  {'text': 'has to ruin it by getting too excited',
#   'start': 399.08,
#   'duration': 5.04},
#  {'text': 'and creating a big hole in the', 'start': 401.52, 'duration': 4.88},
#  {'text': "bottom I can't let it go to waste so",
#   'start': 404.12,
#   'duration': 4.28},
#  {'text': "this one go down so and then I'll do the",
#   'start': 406.4,
#   'duration': 5.199},
#  {'text': 'last one with lots of', 'start': 408.4, 'duration': 3.199},
#  {'text': 'spice even though I put loads of spice',
#   'start': 413.68,
#   'duration': 4.519},
#  {'text': "in there that's not the overriding",
#   'start': 416.52,
#   'duration': 3.2},
#  {'text': 'flavor', 'start': 418.199, 'duration': 3.72},
#  {'text': "doesn't kill everything although my",
#   'start': 419.72,
#   'duration': 3.96},
#  {'text': 'mouth is tingling', 'start': 421.919, 'duration': 4.801},
#  {'text': 'away as a starter one is a bit of',
#   'start': 423.68,
#   'duration': 4.44},
#  {'text': 'theater but', 'start': 426.72, 'duration': 3.479},
#  {'text': 'two is the', 'start': 428.12, 'duration': 5.32},
#  {'text': 'flavor the flavors are incredible and',
#   'start': 430.199,
#   'duration': 5.601},
#  {'text': 'that is coming from these chickpeas and',
#   'start': 433.44,
#   'duration': 4.72},
#  {'text': "The Tamarind that's the overriding",
#   'start': 435.8,
#   'duration': 4.399},
#  {'text': 'flavor and that is a nice little bit of',
#   'start': 438.16,
#   'duration': 3.479},
#  {'text': 'heat to go on', 'start': 440.199, 'duration': 4.68},
#  {'text': "top as a starter that's incredible that",
#   'start': 441.639,
#   'duration': 4.921},
#  {'text': 'has really got me', 'start': 444.879, 'duration': 6.201},
#  {'text': 'excited and yeah what can I say the only',
#   'start': 446.56,
#   'duration': 7.079},
#  {'text': "thing I can say is I'm going to finish",
#   'start': 451.08,
#   'duration': 4.76},
#  {'text': 'enjoy the other thing about it as well',
#   'start': 453.639,
#   'duration': 4.56},
#  {'text': "it's quite a light starter so that",
#   'start': 455.84,
#   'duration': 5.24},
#  {'text': 'really helps so again with um Curry it',
#   'start': 458.199,
#   'duration': 6.28},
#  {'text': 'can be a little bit too heavy but this',
#   'start': 461.08,
#   'duration': 7.32},
#  {'text': 'well very very long ping pong',
#   'start': 464.479,
#   'duration': 7.801},
#  {'text': 'balls edible ping pong balls okay I',
#   'start': 468.4,
#   'duration': 9.32},
#  {'text': 'shall see you very soon great starter',
#   'start': 472.28,
#   'duration': 5.44},
#  {'text': '[Music]', 'start': 480.05, 'duration': 9.229},
#  {'text': '[Music]', 'start': 496.44, 'duration': 4.57},
#  {'text': 'here we', 'start': 503.24, 'duration': 5.239},
#  {'text': "go I'm actually really excited this my",
#   'start': 504.84,
#   'duration': 6.6},
#  {'text': 'prawn going', 'start': 508.479, 'duration': 2.961},
#  {'text': 'Curry oh wow wow wow the aroma wow wow',
#   'start': 513.12,
#   'duration': 4.799},
#  {'text': 'wow wow wow', 'start': 516.279, 'duration': 4.76},
#  {'text': 'wow then so I give that a bit of stir so',
#   'start': 517.919,
#   'duration': 7.441},
#  {'text': 'you can actually see oh Cy look at these',
#   'start': 521.039,
#   'duration': 4.321},
#  {'text': 'prawns', 'start': 527.44, 'duration': 6.36},
#  {'text': 'lovely then the chicken butter', 'start': 529.24, 'duration': 6.96},
#  {'text': 'masala now this is their signature dish',
#   'start': 533.8,
#   'duration': 6.599},
#  {'text': 'this is what everyone goes for', 'start': 536.2, 'duration': 4.199},
#  {'text': "I've got to be very careful here very",
#   'start': 541.44,
#   'duration': 4.839},
#  {'text': 'careful cuz I do not want to spill a',
#   'start': 543.48,
#   'duration': 6.08},
#  {'text': 'single drop at these', 'start': 546.279, 'duration': 5.841},
#  {'text': 'prices bread baskets over here so you',
#   'start': 549.56,
#   'duration': 4.839},
#  {'text': 'have the coriander one you got some',
#   'start': 552.12,
#   'duration': 5.36},
#  {'text': "plain Nar and that's a oh that's a",
#   'start': 554.399,
#   'duration': 5.88},
#  {'text': 'stuffed one and Gary stuffs it all up as',
#   'start': 557.48,
#   'duration': 7.64},
#  {'text': "well I'm going to do let's get the",
#   'start': 560.279,
#   'duration': 4.841},
#  {'text': 'plane plates are lovely and warm',
#   'start': 566.88,
#   'duration': 7.04},
#  {'text': "the Nan equally so I'm just going to get",
#   'start': 570.64,
#   'duration': 6.0},
#  {'text': 'in here and I want to try this', 'start': 573.92, 'duration': 6.52},
#  {'text': 'sauce as I say this is their', 'start': 576.64, 'duration': 6.28},
#  {'text': 'signature so this is the one everyone',
#   'start': 580.44,
#   'duration': 5.04},
#  {'text': 'goes mad', 'start': 582.92, 'duration': 2.56},
#  {'text': "about I'm going to say the obious is",
#   'start': 597.88,
#   'duration': 4.56},
#  {'text': "there it's buttery it's creamy but it",
#   'start': 599.8,
#   'duration': 5.2},
#  {'text': 'has a little little bit of heat a little',
#   'start': 602.44,
#   'duration': 6.32},
#  {'text': "bit of kick but I've um wow I don't know",
#   'start': 605.0,
#   'duration': 5.16},
#  {'text': 'how they make that in that', 'start': 608.76, 'duration': 4.72},
#  {'text': "kitchen with that sauce no I can't judge",
#   'start': 610.16,
#   'duration': 6.04},
#  {'text': "it on one so let's pick it up let's have",
#   'start': 613.48,
#   'duration': 4.76},
#  {'text': 'a bit of chicken on the', 'start': 616.2, 'duration': 6.04},
#  {'text': 'plate a bit of chicken', 'start': 618.24, 'duration': 4.0},
#  {'text': "GES let's put that", 'start': 622.6, 'duration': 5.239},
#  {'text': "there lots of this sauce this can't got",
#   'start': 625.04,
#   'duration': 4.919},
#  {'text': 'to waste on', 'start': 627.839, 'duration': 4.521},
#  {'text': 'there I want to try that with some of',
#   'start': 629.959,
#   'duration': 3.641},
#  {'text': 'the', 'start': 632.36, 'duration': 4.4},
#  {'text': "rice get that there let's try try it",
#   'start': 633.6,
#   'duration': 6.08},
#  {'text': 'with just a little bit of', 'start': 636.76, 'duration': 2.92},
#  {'text': 'rice', 'start': 640.44, 'duration': 3.0},
#  {'text': 'so give myself in a bit of a kafuffle',
#   'start': 643.6,
#   'duration': 6.52},
#  {'text': "here it's cut into the", 'start': 646.32, 'duration': 3.8},
#  {'text': 'chicken to say that chicken is tender',
#   'start': 650.6,
#   'duration': 5.28},
#  {'text': 'pulls away his', 'start': 653.8, 'duration': 4.92},
#  {'text': "understatement it's just come on let's",
#   'start': 655.88,
#   'duration': 6.68},
#  {'text': 'get with it in there in', 'start': 658.72, 'duration': 3.84},
#  {'text': "there that's chicken thigh and what I",
#   'start': 665.48,
#   'duration': 5.4},
#  {'text': 'like the chicken thigh that has got so',
#   'start': 668.6,
#   'duration': 4.96},
#  {'text': 'much flavor so again you have the lights',
#   'start': 670.88,
#   'duration': 5.28},
#  {'text': "the chicken breast and again that's very",
#   'start': 673.56,
#   'duration': 5.48},
#  {'text': 'tasty but the thigh is where all the',
#   'start': 676.16,
#   'duration': 5.88},
#  {'text': 'flavor in a chicken is the meat itself',
#   'start': 679.04,
#   'duration': 5.72},
#  {'text': 'the chicken is super tender that is',
#   'start': 682.04,
#   'duration': 7.52},
#  {'text': 'elevated to a level way above any butter',
#   'start': 684.76,
#   'duration': 6.44},
#  {'text': "chicken curry I've ever had butter",
#   'start': 689.56,
#   'duration': 6.519},
#  {'text': "chicken masala Curry I've ever had it is",
#   'start': 691.2,
#   'duration': 7.92},
#  {'text': 'so incredible I was going to say intense',
#   'start': 696.079,
#   'duration': 6.2},
#  {'text': "but it isn't the intense it's incredible",
#   'start': 699.12,
#   'duration': 6.959},
#  {'text': "it's incredible cooking yeah the sheen",
#   'start': 702.279,
#   'duration': 5.721},
#  {'text': 'to it as well I mean come if you take a',
#   'start': 706.079,
#   'duration': 4.961},
#  {'text': 'look at this look at that for a', 'start': 708.0, 'duration': 6.24},
#  {'text': "Sheen it's just inviting and obviously",
#   'start': 711.04,
#   'duration': 6.64},
#  {'text': 'you got herbs in there as well on top I',
#   'start': 714.24,
#   'duration': 5.48},
#  {'text': 'keep I keep actually ping away and',
#   'start': 717.68,
#   'duration': 4.48},
#  {'text': 'getting more and more without tasting it',
#   'start': 719.72,
#   'duration': 4.72},
#  {'text': 'which is', 'start': 722.16, 'duration': 2.28},
#  {'text': 'madness that goes down as one of the',
#   'start': 725.399,
#   'duration': 9.0},
#  {'text': 'best what is so clever it does catch you',
#   'start': 729.959,
#   'duration': 7.401},
#  {'text': 'and it kind of Fades away not mad about',
#   'start': 734.399,
#   'duration': 5.24},
#  {'text': 'your spice do let them know cuz there is',
#   'start': 737.36,
#   'duration': 4.12},
#  {'text': "that kick it's not unpleasant please",
#   'start': 739.639,
#   'duration': 4.081},
#  {'text': "don't think that but it does catch you",
#   'start': 741.48,
#   'duration': 4.88},
#  {'text': 'and that caught me just in I was I say',
#   'start': 743.72,
#   'duration': 6.32},
#  {'text': "that I'm bit of a spice wuss as well so",
#   'start': 746.36,
#   'duration': 6.36},
#  {'text': "would I say that is incredible and I'm",
#   'start': 750.04,
#   'duration': 4.359},
#  {'text': "I'm really sorry to say but it is",
#   'start': 752.72,
#   'duration': 2.84},
#  {'text': 'totally', 'start': 754.399, 'duration': 4.161},
#  {'text': 'incredible um yeah I can understand why',
#   'start': 755.56,
#   'duration': 5.36},
#  {'text': "it's a signature dish what I want to do",
#   'start': 758.56,
#   'duration': 5.519},
#  {'text': 'is get in finish this clear the plate',
#   'start': 760.92,
#   'duration': 4.479},
#  {'text': "and in fact what I'm going to do is get",
#   'start': 764.079,
#   'duration': 3.401},
#  {'text': 'another plate a complete new plate and I',
#   'start': 765.399,
#   'duration': 5.761},
#  {'text': 'want to try the prawns Goen', 'start': 767.48, 'duration': 7.32},
#  {'text': "prawn Curry I'll see you very very soon",
#   'start': 771.16,
#   'duration': 6.799},
#  {'text': 'brilliant nor brilliant nor it starts to',
#   'start': 774.8,
#   'duration': 5.24},
#  {'text': 'get very busy here and some people have',
#   'start': 777.959,
#   'duration': 4.161},
#  {'text': 'joined us next on the table next to us',
#   'start': 780.04,
#   'duration': 3.56},
#  {'text': "lovely people I've got to say really",
#   'start': 782.12,
#   'duration': 3.24},
#  {'text': "nice but I don't want to disturb them at",
#   'start': 783.6,
#   'duration': 3.2},
#  {'text': 'all', 'start': 785.36, 'duration': 4.68},
#  {'text': "so take a look here as you've seen",
#   'start': 786.8,
#   'duration': 6.279},
#  {'text': 'before now what the chat has said to me',
#   'start': 790.04,
#   'duration': 4.64},
#  {'text': 'this should be a little bit', 'start': 793.079, 'duration': 5.161},
#  {'text': 'sour a little bit of heat with it as in',
#   'start': 794.68,
#   'duration': 8.8},
#  {'text': 'spice and he said the prawns should just',
#   'start': 798.24,
#   'duration': 9.88},
#  {'text': "melt let's get plenty of the", 'start': 803.48, 'duration': 6.88},
#  {'text': 'sauce that sauce is a lot', 'start': 808.12, 'duration': 5.399},
#  {'text': "thinner so this one's quite a dense",
#   'start': 810.36,
#   'duration': 5.839},
#  {'text': 'sauce this one here is a lot thinner',
#   'start': 813.519,
#   'duration': 4.041},
#  {'text': "they're quite similar in color but i'",
#   'start': 816.199,
#   'duration': 3.76},
#  {'text': 'imagine totally different in flavor and',
#   'start': 817.56,
#   'duration': 5.76},
#  {'text': "taste so let's cut", 'start': 819.959, 'duration': 3.361},
#  {'text': 'in and see what we', 'start': 824.079, 'duration': 5.44},
#  {'text': 'think I want to get plenty of this sauce',
#   'start': 826.8,
#   'duration': 5.719},
#  {'text': 'there', 'start': 829.519, 'duration': 3.0},
#  {'text': "that's", 'start': 840.36, 'duration': 5.039},
#  {'text': 'exactly as he said sauce is a little bit',
#   'start': 842.0,
#   'duration': 6.16},
#  {'text': 'on a little bit s not sour that sounds',
#   'start': 845.399,
#   'duration': 5.721},
#  {'text': "wrong it's got a slight sourness and",
#   'start': 848.16,
#   'duration': 6.08},
#  {'text': 'then a heat creaminess as well to',
#   'start': 851.12,
#   'duration': 6.12},
#  {'text': "it and it's got a a hint there's no",
#   'start': 854.24,
#   'duration': 4.48},
#  {'text': "doubt there's fish stock in there as",
#   'start': 857.24,
#   'duration': 3.8},
#  {'text': "well so there's nice amount of fish",
#   'start': 858.72,
#   'duration': 5.679},
#  {'text': 'stock the prawns', 'start': 861.04, 'duration': 8.28},
#  {'text': "are CRS I've only have one", 'start': 864.399, 'duration': 4.921},
#  {'text': "Sensational that that's a taste of the",
#   'start': 870.399,
#   'duration': 6.761},
#  {'text': "ocean I've never been to goer I'm going",
#   'start': 873.959,
#   'duration': 5.761},
#  {'text': "to go to go cuz if that's what it's all",
#   'start': 877.16,
#   'duration': 5.28},
#  {'text': 'about yeah you taste Tamarind in there',
#   'start': 879.72,
#   'duration': 4.52},
#  {'text': 'and I understand hello there I hope you',
#   'start': 882.44,
#   'duration': 3.759},
#  {'text': 'enjing your lunch I can tell you this is',
#   'start': 884.24,
#   'duration': 3.92},
#  {'text': 'absolutely fabulous thank you so the',
#   'start': 886.199,
#   'duration': 3.76},
#  {'text': 'chef has just come out to say hello here',
#   'start': 888.16,
#   'duration': 3.28},
#  {'text': 'I got to say this is some incredible',
#   'start': 889.959,
#   'duration': 4.12},
#  {'text': 'cooking so thank you very very much Chef',
#   'start': 891.44,
#   'duration': 4.56},
#  {'text': 'thank you thank', 'start': 894.079, 'duration': 4.161},
#  {'text': "you he's going around to the tables just",
#   'start': 896.0,
#   'duration': 3.36},
#  {'text': "making sure everything's good good what",
#   'start': 898.24,
#   'duration': 3.519},
#  {'text': 'a touch that is a fantastic touch just',
#   'start': 899.36,
#   'duration': 4.919},
#  {'text': 'for the chef to come out so as I said',
#   'start': 901.759,
#   'duration': 5.561},
#  {'text': "one of Rick Stein's U most favorite",
#   'start': 904.279,
#   'duration': 5.281},
#  {'text': "dishes but I'm not taking any notice of",
#   'start': 907.32,
#   'duration': 3.319},
#  {'text': 'Rick at the moment because me and him',
#   'start': 909.56,
#   'duration': 2.639},
#  {'text': "are not mates I'm I'm not sending him a",
#   'start': 910.639,
#   'duration': 3.88},
#  {'text': "Christmas card that's for", 'start': 912.199, 'duration': 5.601},
#  {'text': 'sure but I want to try it with this naan',
#   'start': 914.519,
#   'duration': 6.921},
#  {'text': "with coriander in it let's just see have",
#   'start': 917.8,
#   'duration': 5.959},
#  {'text': 'I made a good have I made a good call or',
#   'start': 921.44,
#   'duration': 4.759},
#  {'text': "good choice or should I've actually gone",
#   'start': 923.759,
#   'duration': 5.401},
#  {'text': 'with just a plane', 'start': 926.199, 'duration': 5.161},
#  {'text': 'I definitely made a good call', 'start': 929.16, 'duration': 4.56},
#  {'text': "getting the king pra Curry there's no",
#   'start': 931.36,
#   'duration': 4.919},
#  {'text': 'doubts about', 'start': 933.72, 'duration': 2.559},
#  {'text': 'that if you take a', 'start': 938.24, 'duration': 6.32},
#  {'text': "look there's so much fresh coriander in",
#   'start': 941.36,
#   'duration': 4.24},
#  {'text': 'that', 'start': 944.56, 'duration': 4.44},
#  {'text': 'Mom what do I', 'start': 945.6, 'duration': 3.4},
#  {'text': "think I think I'm very lucky I am I'm",
#   'start': 949.759,
#   'duration': 7.401},
#  {'text': 'very lucky because this is a super',
#   'start': 953.959,
#   'duration': 5.281},
#  {'text': 'high-end treat', 'start': 957.16, 'duration': 4.359},
#  {'text': "and I won't get the privilege of coming",
#   'start': 959.24,
#   'duration': 4.039},
#  {'text': 'here very often I imagine quite a few',
#   'start': 961.519,
#   'duration': 5.361},
#  {'text': 'people would struggle coming here but as',
#   'start': 963.279,
#   'duration': 5.441},
#  {'text': 'an', 'start': 966.88, 'duration': 6.16},
#  {'text': 'experience wow I am um is it the simple',
#   'start': 968.72,
#   'duration': 6.52},
#  {'text': 'thing ver schami was up there and it was',
#   'start': 973.04,
#   'duration': 3.84},
#  {'text': "fantastic is that a level above you're",
#   'start': 975.24,
#   'duration': 3.839},
#  {'text': 'going to have to wait I will tell you',
#   'start': 976.88,
#   'duration': 6.6},
#  {'text': 'shortly but wow wow wow wow and wow see',
#   'start': 979.079,
#   'duration': 5.24},
#  {'text': 'you', 'start': 983.48, 'duration': 4.919},
#  {'text': 'soon here we have the mea desserts',
#   'start': 984.319,
#   'duration': 5.32},
#  {'text': 'taking a look look through you take a',
#   'start': 988.399,
#   'duration': 2.88},
#  {'text': "look through it yourself what I've I",
#   'start': 989.639,
#   'duration': 3.76},
#  {'text': "going for I'm looking here I'm going to",
#   'start': 991.279,
#   'duration': 3.881},
#  {'text': "go for their um basically I'm going to",
#   'start': 993.399,
#   'duration': 4.321},
#  {'text': 'go for the Indian rice', 'start': 995.16, 'duration': 4.799},
#  {'text': "pudding I'll explain it all soon it's",
#   'start': 997.72,
#   'duration': 5.28},
#  {'text': 'got figs in there yeah just about',
#   'start': 999.959,
#   'duration': 5.8},
#  {'text': "everything and that's £10 and here it is",
#   'start': 1003.0,
#   'duration': 4.759},
#  {'text': 'right on Q if I can leave that over',
#   'start': 1005.759,
#   'duration': 6.88},
#  {'text': 'there look at this for', 'start': 1007.759, 'duration': 4.88},
#  {'text': 'presentation now I picked that up',
#   'start': 1012.8,
#   'duration': 3.88},
#  {'text': 'earlier on and look I managed to break',
#   'start': 1014.56,
#   'duration': 5.399},
#  {'text': 'it already because it is so delicate',
#   'start': 1016.68,
#   'duration': 6.48},
#  {'text': "moving that and I've done it",
#   'start': 1019.959,
#   'duration': 6.281},
#  {'text': 'again take a look in here so you have',
#   'start': 1023.16,
#   'duration': 4.2},
#  {'text': 'figs in', 'start': 1026.24, 'duration': 4.76},
#  {'text': 'there obviously the rice and this is ice',
#   'start': 1027.36,
#   'duration': 6.4},
#  {'text': 'cream in the middle as', 'start': 1031.0, 'duration': 4.799},
#  {'text': 'well well this is certainly a different',
#   'start': 1033.76,
#   'duration': 3.799},
#  {'text': "take isn't it on rice", 'start': 1035.799, 'duration': 3.441},
#  {'text': "pudding I'll tell you what I'm going to",
#   'start': 1037.559,
#   'duration': 3.601},
#  {'text': "do I'm going to move that over there and",
#   'start': 1039.24,
#   'duration': 4.04},
#  {'text': 'move this right in front of', 'start': 1041.16, 'duration': 4.679},
#  {'text': 'me break every etiquette in the whole',
#   'start': 1043.28,
#   'duration': 5.559},
#  {'text': 'book', 'start': 1045.839, 'duration': 3.0},
#  {'text': '[Music]', 'start': 1050.04, 'duration': 3.23},
#  {'text': "it's not like any rice pudding I've ever",
#   'start': 1053.44,
#   'duration': 6.2},
#  {'text': "had and taste the figs there then it's",
#   'start': 1055.72,
#   'duration': 7.12},
#  {'text': 'got some some spices around it not as in',
#   'start': 1059.64,
#   'duration': 7.0},
#  {'text': 'hot spices but', 'start': 1062.84, 'duration': 3.8},
#  {'text': 'spices that is one of the most Pleasant',
#   'start': 1070.799,
#   'duration': 7.12},
#  {'text': 'my SPS overhead I sitting here thinking',
#   'start': 1075.44,
#   'duration': 4.28},
#  {'text': 'will this bring me back my school days',
#   'start': 1077.919,
#   'duration': 3.281},
#  {'text': 'and all the rest of it having rice',
#   'start': 1079.72,
#   'duration': 2.92},
#  {'text': "pudding no I've never had anything like",
#   'start': 1081.2,
#   'duration': 3.16},
#  {'text': 'this before try it with some of the ice',
#   'start': 1082.64,
#   'duration': 3.919},
#  {'text': 'cream but I want you take a look so you',
#   'start': 1084.36,
#   'duration': 4.64},
#  {'text': 'obviously see whole figs in', 'start': 1086.559, 'duration': 6.36},
#  {'text': "there it's all the spilling of",
#   'start': 1089.0,
#   'duration': 3.919},
#  {'text': "it that's very", 'start': 1096.2, 'duration': 4.599},
#  {'text': "rich also taste some there's some",
#   'start': 1098.36,
#   'duration': 5.92},
#  {'text': 'pistach pistachio nuts in there as',
#   'start': 1100.799,
#   'duration': 5.681},
#  {'text': 'well that is just', 'start': 1104.28, 'duration': 4.04},
#  {'text': "something trying to tell what it is it's",
#   'start': 1106.48,
#   'duration': 4.28},
#  {'text': 'super add', 'start': 1108.32, 'duration': 2.44},
#  {'text': "now I'm going to get the", 'start': 1113.919, 'duration': 3.321},
#  {'text': 'bill give my final thoughts outside was',
#   'start': 1117.28,
#   'duration': 6.399},
#  {'text': 'that a good call it was a good call I',
#   'start': 1120.52,
#   'duration': 4.08},
#  {'text': "was thinking I'm not going to get a",
#   'start': 1123.679,
#   'duration': 4.641},
#  {'text': 'deser I am or I am I have and just',
#   'start': 1124.6,
#   'duration': 7.12},
#  {'text': 'finishes the meal just finishes it off',
#   'start': 1128.32,
#   'duration': 6.839},
#  {'text': 'finishes off a truly', 'start': 1131.72, 'duration': 7.36},
#  {'text': 'wonderful not meal experience',
#   'start': 1135.159,
#   'duration': 8.281},
#  {'text': 'a fantastic experience see', 'start': 1139.08, 'duration': 6.68},
#  {'text': 'outside Jim carner one of the most',
#   'start': 1143.44,
#   'duration': 3.96},
#  {'text': 'expensive and one of the best Indian',
#   'start': 1145.76,
#   'duration': 4.84},
#  {'text': 'restaurants in the world I can confirm',
#   'start': 1147.4,
#   'duration': 6.0},
#  {'text': 'both I love the inside I love the',
#   'start': 1150.6,
#   'duration': 5.439},
#  {'text': 'service I like the ambience everything',
#   'start': 1153.4,
#   'duration': 6.2},
#  {'text': 'on there was top draw the food wow wow',
#   'start': 1156.039,
#   'duration': 8.961},
#  {'text': 'wow wow seriously that food was truly',
#   'start': 1159.6,
#   'duration': 8.52},
#  {'text': 'incredible every mouthful every every',
#   'start': 1165.0,
#   'duration': 5.32},
#  {'text': 'aspect of it you put it in it had the',
#   'start': 1168.12,
#   'duration': 5.0},
#  {'text': 'flavor oh it it was brilliant cameraman',
#   'start': 1170.32,
#   'duration': 4.8},
#  {'text': 'he loved it as well so both of us',
#   'start': 1173.12,
#   'duration': 5.84},
#  {'text': 'thought that was great onto the',
#   'start': 1175.12,
#   'duration': 3.84},
#  {'text': 'bill starter', 'start': 1181.44, 'duration': 5.92},
#  {'text': '12250 uh that butter masala £32 the',
#   'start': 1183.559,
#   'duration': 7.321},
#  {'text': 'prawn Curry £ 33b Bread Basket',
#   'start': 1187.36,
#   'duration': 7.16},
#  {'text': '12250 uh the rice £7 and the dessert uh',
#   'start': 1190.88,
#   'duration': 9.36},
#  {'text': '£10 service charge in there uh 15% 12 £',
#   'start': 1194.52,
#   'duration': 7.36},
#  {'text': '3£', 'start': 1200.24, 'duration': 4.48},
#  {'text': "123 that's mindblowing In fairness I did",
#   'start': 1201.88,
#   'duration': 4.44},
#  {'text': 'order a lot there there enough for two',
#   'start': 1204.72,
#   'duration': 3.56},
#  {'text': "people but that's still an awful lot of",
#   'start': 1206.32,
#   'duration': 4.32},
#  {'text': 'money but then again I am looking at',
#   'start': 1208.28,
#   'duration': 4.639},
#  {'text': 'quality would I come here all the time',
#   'start': 1210.64,
#   'duration': 3.88},
#  {'text': 'you know would I come here all the time',
#   'start': 1212.919,
#   'duration': 5.401},
#  {'text': "no no there's no chance but would is it",
#   'start': 1214.52,
#   'duration': 6.039},
#  {'text': 'somewhere you would go for that really',
#   'start': 1218.32,
#   'duration': 3.96},
#  {'text': 'special occasion yeah enough food for',
#   'start': 1220.559,
#   'duration': 3.281},
#  {'text': 'two people you got to remember that the',
#   'start': 1222.28,
#   'duration': 2.72},
#  {'text': "other thing which I've got to tell you",
#   'start': 1223.84,
#   'duration': 2.8},
#  {'text': "if I'm actually coming back the one",
#   'start': 1225.0,
#   'duration': 3.84},
#  {'text': 'thing I would look at is their set menu',
#   'start': 1226.64,
#   'duration': 3.36},
#  {'text': 'because obviously the portions are',
#   'start': 1228.84,
#   'duration': 2.64},
#  {'text': "exactly the same size and I think that's",
#   'start': 1230.0,
#   'duration': 2.799},
#  {'text': "actual better way to go if you're going",
#   'start': 1231.48,
#   'duration': 3.8},
#  {'text': 'in there lunchtime evening time yeah I',
#   'start': 1232.799,
#   'duration': 3.961},
#  {'text': 'try and mix up the price points on the',
#   'start': 1235.28,
#   'duration': 3.279},
#  {'text': "channel so yeah I I'll go and do fish",
#   'start': 1236.76,
#   'duration': 3.24},
#  {'text': "and chips three pound and I'll go to",
#   'start': 1238.559,
#   'duration': 3.681},
#  {'text': 'michan Star restaurants as well and I do',
#   'start': 1240.0,
#   'duration': 3.96},
#  {'text': 'prices in between I try and really mix',
#   'start': 1242.24,
#   'duration': 3.76},
#  {'text': 'it up and I want to try and showcase',
#   'start': 1243.96,
#   'duration': 5.24},
#  {'text': 'certain places that In fairness you know',
#   'start': 1246.0,
#   'duration': 4.84},
#  {'text': "I've never been here before and ibly",
#   'start': 1249.2,
#   'duration': 5.2},
#  {'text': "won't come here maybe ever again but",
#   'start': 1250.84,
#   'duration': 6.36},
#  {'text': "that's an experience an experience that",
#   'start': 1254.4,
#   'duration': 5.08},
#  {'text': 'if you get the opportunity', 'start': 1257.2, 'duration': 4.32},
#  {'text': 'definitely definitely give it a go',
#   'start': 1259.48,
#   'duration': 4.28},
#  {'text': "certainly at the high end I'm not silly",
#   'start': 1261.52,
#   'duration': 4.519},
#  {'text': "it's really at the high end what marks",
#   'start': 1263.76,
#   'duration': 3.399},
#  {'text': "I'm going to give", 'start': 1266.039, 'duration': 4.12},
#  {'text': 'it loads of you recommended fantastic',
#   'start': 1267.159,
#   'duration': 6.0},
#  {'text': "recommendation it's quality that's the",
#   'start': 1270.159,
#   'duration': 5.161},
#  {'text': "thing that's the standout quality in",
#   'start': 1273.159,
#   'duration': 4.441},
#  {'text': 'every aspect every', 'start': 1275.32, 'duration': 4.88},
#  {'text': "aspect I'm going to give it a 10 out of",
#   'start': 1277.6,
#   'duration': 5.36},
#  {'text': "10 I've got to give it a 10 out of 10",
#   'start': 1280.2,
#   'duration': 5.92},
#  {'text': 'because each dish that I had there was',
#   'start': 1282.96,
#   'duration': 5.319},
#  {'text': "amongst the best if not the best I've",
#   'start': 1286.12,
#   'duration': 4.96},
#  {'text': 'ever had in any Indian restaurant ever',
#   'start': 1288.279,
#   'duration': 4.561},
#  {'text': 'and I love the whole', 'start': 1291.08, 'duration': 4.16},
#  {'text': 'experience if you recommended Jim carner',
#   'start': 1292.84,
#   'duration': 4.079},
#  {'text': 'I want to thank you personally thank you',
#   'start': 1295.24,
#   'duration': 4.0},
#  {'text': "very very much if you've been here",
#   'start': 1296.919,
#   'duration': 3.841},
#  {'text': 'please tell me what you think if you can',
#   'start': 1299.24,
#   'duration': 3.2},
#  {'text': 'like And subscribe to the channel you',
#   'start': 1300.76,
#   'duration': 5.039},
#  {'text': 'know I always appreciate that and until',
#   'start': 1302.44,
#   'duration': 5.599},
#  {'text': 'next', 'start': 1305.799, 'duration': 2.24},
#  {'text': 'time very lucky person and I recognize',
#   'start': 1308.159,
#   'duration': 5.64},
#  {'text': 'that', 'start': 1312.039, 'duration': 5.041},
#  {'text': 'bye-bye that was a brilliant', 'start': 1313.799, 'duration': 5.12},
#  {'text': 'recommendation', 'start': 1317.08, 'duration': 4.839},
#  {'text': 'w', 'start': 1318.919, 'duration': 3.0}]

# %% [markdown]
# ## Step 1b - Indexing (Text Splitting)

# %%
splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
chunks = splitter.create_documents([transcript])

# %%
len(chunks)
# Out:
# 19

# %%
chunks[18]
# Out:
# Document(metadata={}, page_content="but that's an experience an experience that if you get the opportunity definitely definitely give it a go certainly at the high end I'm not silly it's really at the high end what marks I'm going to give it loads of you recommended fantastic recommendation it's quality that's the thing that's the standout quality in every aspect every aspect I'm going to give it a 10 out of 10 I've got to give it a 10 out of 10 because each dish that I had there was amongst the best if not the best I've ever had in any Indian restaurant ever and I love the whole experience if you recommended Jim carner I want to thank you personally thank you very very much if you've been here please tell me what you think if you can like And subscribe to the channel you know I always appreciate that and until next time very lucky person and I recognize that bye-bye that was a brilliant recommendation w")

# %% [markdown]
# ## Step 1c & 1d - Indexing (Embedding Generation and Storing in Vector Store)

# %%
embeddings = HuggingFaceEmbeddings(model_name='sentence-transformers/all-MiniLM-L6-v2')
vector_store = FAISS.from_documents(chunks, embeddings)

# %%
vector_store.index_to_docstore_id
# Out:
# {0: '07fa68dd-99c0-4f89-8942-36a85dfec4c4',
#  1: '9ae5aa62-150b-4013-8992-c66e67afe6ac',
#  2: '44d49128-bf66-4472-adba-bacc1628ec97',
#  3: 'fc99891e-12b1-4179-9925-019f1024ed2d',
#  4: '2badafd6-bd5f-4288-8f3d-ba5268c6d557',
#  5: 'fb499053-54ac-48fc-9a65-6320618fea51',
#  6: '4c372e0a-a556-4314-bb19-8d1c03084a4e',
#  7: '5d63c436-2b91-449f-a765-66db23599cc5',
#  8: '8d3caeb2-e2eb-412d-96f0-8bcd8689ca38',
#  9: '696a22a4-d393-4424-82b2-20f6c2b39f5f',
#  10: 'bae240c2-7326-4601-8306-8e8986e637ae',
#  11: 'cf3c35e3-8327-4dd6-bda9-c0afe91c0ba1',
#  12: 'cf3fa3a9-ec44-434a-baba-725c896e018b',
#  13: '292da20e-a7ac-4c48-a069-66e61c4291e3',
#  14: '1c5c9e7a-3d09-4a75-bc98-02c9cc182f23',
#  15: '1fbc013c-bfcb-4e90-b86e-aa7c80d8aa36',
#  16: 'ebae6af9-a237-48fb-8c4a-5def6b899410',
#  17: 'f113aba7-8790-4c95-8810-813197ca3475',
#  18: '1a0b0e9c-60ee-43f4-93da-c54157631990'}

# %%
vector_store.get_by_ids(['a1c27a4d-37ab-4047-99f8-5f4090c2b93d'])
# Out:
# []

# %% [markdown]
# ## Step 2 - Retrieval

# %%
retriever = vector_store.as_retriever(search_type="similarity", search_kwargs={"k": 4})

# %%
retriever
# Out:
# VectorStoreRetriever(tags=['FAISS', 'HuggingFaceEmbeddings'], vectorstore=<langchain_community.vectorstores.faiss.FAISS object at 0x000002B21AC8F4A0>, search_kwargs={'k': 4})

# %%
retriever.invoke('What is the best dish here')
# Out:
# [Document(id='1a0b0e9c-60ee-43f4-93da-c54157631990', metadata={}, page_content="but that's an experience an experience that if you get the opportunity definitely definitely give it a go certainly at the high end I'm not silly it's really at the high end what marks I'm going to give it loads of you recommended fantastic recommendation it's quality that's the thing that's the standout quality in every aspect every aspect I'm going to give it a 10 out of 10 I've got to give it a 10 out of 10 because each dish that I had there was amongst the best if not the best I've ever had in any Indian restaurant ever and I love the whole experience if you recommended Jim carner I want to thank you personally thank you very very much if you've been here please tell me what you think if you can like And subscribe to the channel you know I always appreciate that and until next time very lucky person and I recognize that bye-bye that was a brilliant recommendation w"),
#  Document(id='1fbc013c-bfcb-4e90-b86e-aa7c80d8aa36', metadata={}, page_content="in hot spices but spices that is one of the most Pleasant my SPS overhead I sitting here thinking will this bring me back my school days and all the rest of it having rice pudding no I've never had anything like this before try it with some of the ice cream but I want you take a look so you obviously see whole figs in there it's all the spilling of it that's very rich also taste some there's some pistach pistachio nuts in there as well that is just something trying to tell what it is it's super add now I'm going to get the bill give my final thoughts outside was that a good call it was a good call I was thinking I'm not going to get a deser I am or I am I have and just finishes the meal just finishes it off finishes off a truly wonderful not meal experience a fantastic experience see outside Jim carner one of the most expensive and one of the best Indian restaurants in the world I can confirm both I love the inside I love the service I like the ambience everything on there was top"),
#  Document(id='ebae6af9-a237-48fb-8c4a-5def6b899410', metadata={}, page_content="Jim carner one of the most expensive and one of the best Indian restaurants in the world I can confirm both I love the inside I love the service I like the ambience everything on there was top draw the food wow wow wow wow seriously that food was truly incredible every mouthful every every aspect of it you put it in it had the flavor oh it it was brilliant cameraman he loved it as well so both of us thought that was great onto the bill starter 12250 uh that butter masala £32 the prawn Curry £ 33b Bread Basket 12250 uh the rice £7 and the dessert uh £10 service charge in there uh 15% 12 £ 3£ 123 that's mindblowing In fairness I did order a lot there there enough for two people but that's still an awful lot of money but then again I am looking at quality would I come here all the time you know would I come here all the time no no there's no chance but would is it somewhere you would go for that really special occasion yeah enough food for two people you got to remember that the other"),
#  Document(id='44d49128-bf66-4472-adba-bacc1628ec97', metadata={}, page_content="all in all I'm like absolutely stunned it is beautiful truly beautiful this menu it is a tight tight menu um and you'd expect that under naster I'm going to go for the pan of py now what you do here you hollow out then you put the different sources in you put it into your mouth and hopefully it' be an explosion of flavors and that's 12250 I'm very sad very sad I'm looking down lamb shank Rogan Josh I'm get keep getting told off for having lamb okay I won't have it pressure youve put me under pressure um I'm going to go for the Goen prawn Curry that's £33 really interested to see what that looks like and their specialty here a real speciality is their chicken butter masala that's 33 with that I'm going to get a selection of Breads and uh I'm going to get a rice as well uh the Bread Basket IS250 and the rice is £7 all in all wow wow this is just levels levels above uh any Indian restaurant I ever been in my life it is truly truly stunning staff bang super attentive so yeah really")]

# %% [markdown]
# ## Step 3 - Augmentation

# %%
llm = HuggingFacePipeline.from_model_id(
    model_id='google/gemma-2-2b-it',
    task='text-generation',
    pipeline_kwargs=dict(
        temperature=0.5,
        max_new_tokens=100
    ) 
)

model = ChatHuggingFace(llm=llm)
# Out:
# Loading checkpoint shards: 100%|██████████| 2/2 [00:17<00:00,  8.66s/it]
# Device set to use cpu

# %%
prompt = PromptTemplate(
    template="""
      You are a helpful assistant.
      Answer ONLY from the provided transcript context.
      If the context is insufficient, just say you don't know.

      {context}
      Question: {question}
    """,
    input_variables = ['context', 'question']
)

# %%
question          = "is the topic of Indian food discussed in this video? if yes then what was discussed"
retrieved_docs    = retriever.invoke(question)

# %%
retrieved_docs
# Out:
# [Document(id='ebae6af9-a237-48fb-8c4a-5def6b899410', metadata={}, page_content="Jim carner one of the most expensive and one of the best Indian restaurants in the world I can confirm both I love the inside I love the service I like the ambience everything on there was top draw the food wow wow wow wow seriously that food was truly incredible every mouthful every every aspect of it you put it in it had the flavor oh it it was brilliant cameraman he loved it as well so both of us thought that was great onto the bill starter 12250 uh that butter masala £32 the prawn Curry £ 33b Bread Basket 12250 uh the rice £7 and the dessert uh £10 service charge in there uh 15% 12 £ 3£ 123 that's mindblowing In fairness I did order a lot there there enough for two people but that's still an awful lot of money but then again I am looking at quality would I come here all the time you know would I come here all the time no no there's no chance but would is it somewhere you would go for that really special occasion yeah enough food for two people you got to remember that the other"),
#  Document(id='44d49128-bf66-4472-adba-bacc1628ec97', metadata={}, page_content="all in all I'm like absolutely stunned it is beautiful truly beautiful this menu it is a tight tight menu um and you'd expect that under naster I'm going to go for the pan of py now what you do here you hollow out then you put the different sources in you put it into your mouth and hopefully it' be an explosion of flavors and that's 12250 I'm very sad very sad I'm looking down lamb shank Rogan Josh I'm get keep getting told off for having lamb okay I won't have it pressure youve put me under pressure um I'm going to go for the Goen prawn Curry that's £33 really interested to see what that looks like and their specialty here a real speciality is their chicken butter masala that's 33 with that I'm going to get a selection of Breads and uh I'm going to get a rice as well uh the Bread Basket IS250 and the rice is £7 all in all wow wow this is just levels levels above uh any Indian restaurant I ever been in my life it is truly truly stunning staff bang super attentive so yeah really"),
#  Document(id='1fbc013c-bfcb-4e90-b86e-aa7c80d8aa36', metadata={}, page_content="in hot spices but spices that is one of the most Pleasant my SPS overhead I sitting here thinking will this bring me back my school days and all the rest of it having rice pudding no I've never had anything like this before try it with some of the ice cream but I want you take a look so you obviously see whole figs in there it's all the spilling of it that's very rich also taste some there's some pistach pistachio nuts in there as well that is just something trying to tell what it is it's super add now I'm going to get the bill give my final thoughts outside was that a good call it was a good call I was thinking I'm not going to get a deser I am or I am I have and just finishes the meal just finishes it off finishes off a truly wonderful not meal experience a fantastic experience see outside Jim carner one of the most expensive and one of the best Indian restaurants in the world I can confirm both I love the inside I love the service I like the ambience everything on there was top"),
#  Document(id='1a0b0e9c-60ee-43f4-93da-c54157631990', metadata={}, page_content="but that's an experience an experience that if you get the opportunity definitely definitely give it a go certainly at the high end I'm not silly it's really at the high end what marks I'm going to give it loads of you recommended fantastic recommendation it's quality that's the thing that's the standout quality in every aspect every aspect I'm going to give it a 10 out of 10 I've got to give it a 10 out of 10 because each dish that I had there was amongst the best if not the best I've ever had in any Indian restaurant ever and I love the whole experience if you recommended Jim carner I want to thank you personally thank you very very much if you've been here please tell me what you think if you can like And subscribe to the channel you know I always appreciate that and until next time very lucky person and I recognize that bye-bye that was a brilliant recommendation w")]

# %%
context_text = "\n\n".join(doc.page_content for doc in retrieved_docs)
context_text
# Out:
# "Jim carner one of the most expensive and one of the best Indian restaurants in the world I can confirm both I love the inside I love the service I like the ambience everything on there was top draw the food wow wow wow wow seriously that food was truly incredible every mouthful every every aspect of it you put it in it had the flavor oh it it was brilliant cameraman he loved it as well so both of us thought that was great onto the bill starter 12250 uh that butter masala £32 the prawn Curry £ 33b Bread Basket 12250 uh the rice £7 and the dessert uh £10 service charge in there uh 15% 12 £ 3£ 123 that's mindblowing In fairness I did order a lot there there enough for two people but that's still an awful lot of money but then again I am looking at quality would I come here all the time you know would I come here all the time no no there's no chance but would is it somewhere you would go for that really special occasion yeah enough food for two people you got to remember that the other\n\nall in all I'm like absolutely stunned it is beautiful truly beautiful this menu it is a tight tight menu um and you'd expect that under naster I'm going to go for the pan of py now what you do here you hollow out then you put the different sources in you put it into your mouth and hopefully it' be an explosion of flavors and that's 12250 I'm very sad very sad I'm looking down lamb shank Rogan Josh I'm get keep getting told off for having lamb okay I won't have it pressure youve put me under pressure um I'm going to go for the Goen prawn Curry that's £33 really interested to see what that looks like and their specialty here a real speciality is their chicken butter masala that's 33 with that I'm going to get a selection of Breads and uh I'm going to get a rice as well uh the Bread Basket IS250 and the rice is £7 all in all wow wow this is just levels levels above uh any Indian restaurant I ever been in my life it is truly truly stunning staff bang super attentive so yeah really\n\nin hot spices but spices that is one of the most Pleasant my SPS overhead I sitting here thinking will this bring me back my school days and all the rest of it having rice pudding no I've never had anything like this before try it with some of the ice cream but I want you take a look so you obviously see whole figs in there it's all the spilling of it that's very rich also taste some there's some pistach pistachio nuts in there as well that is just something trying to tell what it is it's super add now I'm going to get the bill give my final thoughts outside was that a good call it was a good call I was thinking I'm not going to get a deser I am or I am I have and just finishes the meal just finishes it off finishes off a truly wonderful not meal experience a fantastic experience see outside Jim carner one of the most expensive and one of the best Indian restaurants in the world I can confirm both I love the inside I love the service I like the ambience everything on there was top\n\nbut that's an experience an experience that if you get the opportunity definitely definitely give it a go certainly at the high end I'm not silly it's really at the high end what marks I'm going to give it loads of you recommended fantastic recommendation it's quality that's the thing that's the standout quality in every aspect every aspect I'm going to give it a 10 out of 10 I've got to give it a 10 out of 10 because each dish that I had there was amongst the best if not the best I've ever had in any Indian restaurant ever and I love the whole experience if you recommended Jim carner I want to thank you personally thank you very very much if you've been here please tell me what you think if you can like And subscribe to the channel you know I always appreciate that and until next time very lucky person and I recognize that bye-bye that was a brilliant recommendation w"

# %%
final_prompt = prompt.invoke({"context": context_text, "question": question})

# %%
final_prompt
# Out:
# StringPromptValue(text="\n      You are a helpful assistant.\n      Answer ONLY from the provided transcript context.\n      If the context is insufficient, just say you don't know.\n\n      Jim carner one of the most expensive and one of the best Indian restaurants in the world I can confirm both I love the inside I love the service I like the ambience everything on there was top draw the food wow wow wow wow seriously that food was truly incredible every mouthful every every aspect of it you put it in it had the flavor oh it it was brilliant cameraman he loved it as well so both of us thought that was great onto the bill starter 12250 uh that butter masala £32 the prawn Curry £ 33b Bread Basket 12250 uh the rice £7 and the dessert uh £10 service charge in there uh 15% 12 £ 3£ 123 that's mindblowing In fairness I did order a lot there there enough for two people but that's still an awful lot of money but then again I am looking at quality would I come here all the time you know would I come here all the time no no there's no chance but would is it somewhere you would go for that really special occasion yeah enough food for two people you got to remember that the other\n\nall in all I'm like absolutely stunned it is beautiful truly beautiful this menu it is a tight tight menu um and you'd expect that under naster I'm going to go for the pan of py now what you do here you hollow out then you put the different sources in you put it into your mouth and hopefully it' be an explosion of flavors and that's 12250 I'm very sad very sad I'm looking down lamb shank Rogan Josh I'm get keep getting told off for having lamb okay I won't have it pressure youve put me under pressure um I'm going to go for the Goen prawn Curry that's £33 really interested to see what that looks like and their specialty here a real speciality is their chicken butter masala that's 33 with that I'm going to get a selection of Breads and uh I'm going to get a rice as well uh the Bread Basket IS250 and the rice is £7 all in all wow wow this is just levels levels above uh any Indian restaurant I ever been in my life it is truly truly stunning staff bang super attentive so yeah really\n\nin hot spices but spices that is one of the most Pleasant my SPS overhead I sitting here thinking will this bring me back my school days and all the rest of it having rice pudding no I've never had anything like this before try it with some of the ice cream but I want you take a look so you obviously see whole figs in there it's all the spilling of it that's very rich also taste some there's some pistach pistachio nuts in there as well that is just something trying to tell what it is it's super add now I'm going to get the bill give my final thoughts outside was that a good call it was a good call I was thinking I'm not going to get a deser I am or I am I have and just finishes the meal just finishes it off finishes off a truly wonderful not meal experience a fantastic experience see outside Jim carner one of the most expensive and one of the best Indian restaurants in the world I can confirm both I love the inside I love the service I like the ambience everything on there was top\n\nbut that's an experience an experience that if you get the opportunity definitely definitely give it a go certainly at the high end I'm not silly it's really at the high end what marks I'm going to give it loads of you recommended fantastic recommendation it's quality that's the thing that's the standout quality in every aspect every aspect I'm going to give it a 10 out of 10 I've got to give it a 10 out of 10 because each dish that I had there was amongst the best if not the best I've ever had in any Indian restaurant ever and I love the whole experience if you recommended Jim carner I want to thank you personally thank you very very much if you've been here please tell me what you think if you can like And subscribe to the channel you know I always appreciate that and until next time very lucky person ...

# %% [markdown]
# ## Step 4 - Generation

# %%
answer = model.invoke(final_prompt)
print(answer.content)
# Out:
# g:\coding\GenAI\venv\Lib\site-packages\transformers\generation\configuration_utils.py:631: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.5` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# <bos><start_of_turn>user
# You are a helpful assistant.
#       Answer ONLY from the provided transcript context.
#       If the context is insufficient, just say you don't know.
#
#       Jim carner one of the most expensive and one of the best Indian restaurants in the world I can confirm both I love the inside I love the service I like the ambience everything on there was top draw the food wow wow wow wow seriously that food was truly incredible every mouthful every every aspect of it you put it in it had the flavor oh it it was brilliant cameraman he loved it as well so both of us thought that was great onto the bill starter 12250 uh that butter masala £32 the prawn Curry £ 33b Bread Basket 12250 uh the rice £7 and the dessert uh £10 service charge in there uh 15% 12 £ 3£ 123 that's mindblowing In fairness I did order a lot there there enough for two people but that's still an awful lot of money but then again I am looking at quality would I come here all the time you know would I come here all the time no no there's no chance but would is it somewhere you would go for that really special occasion yeah enough food for two people you got to remember that the other
#
# all in all I'm like absolutely stunned it is beautiful truly beautiful this menu it is a tight tight menu um and you'd expect that under naster I'm going to go for the pan of py now what you do here you hollow out then you put the different sources in you put it into your mouth and hopefully it' be an explosion of flavors and that's 12250 I'm very sad very sad I'm looking down lamb shank Rogan Josh I'm get keep getting told off for having lamb okay I won't have it pressure youve put me under pressure um I'm going to go for the Goen prawn Curry that's £33 really interested to see what that looks like and their specialty here a real speciality is their chicken butter masala that's 33 with that I'm going to get a selection of Breads and uh I'm going to get a rice as well uh the Bread Basket IS250 and the rice is £7 all in all wow wow this is just levels levels above uh any Indian restaurant I ever been in my life it is truly truly stunning staff bang super attentive so yeah really
#
# in hot spices but spices that is one of the most Pleasant my SPS overhead I sitting here thinking will this bring me back my school days and all the rest of it having rice pudding no I've never had anything like this before try it with some of the ice cream but I want you take a look so you obviously see whole figs in there it's all the spilling of it that's very rich also taste some there's some pistach pistachio nuts in there as well that is just something trying to tell what it is it's super add now I'm going to get the bill give my final thoughts outside was that a good call it was a good call I was thinking I'm not going to get a deser I am or I am I have and just finishes the meal just finishes it off finishes off a truly wonderful not meal experience a fantastic experience see outside Jim carner one of the most expensive and one of the best Indian restaurants in the world I can confirm both I love the inside I love the service I like the ambience everything on there was top
#
# but that's an experience an experience that if you get the opportunity definitely definitely give it a go certainly at the high end I'm not silly it's really at the high end what marks I'm going to give it loads of you recommended fantastic recommendation it's quality that's the thing that's the standout quality in every aspect every aspect I'm going to give it a 10 out of 10 I've got to give it a 10 out of 10 because each dish that I had there was amongst the best if not the best I've ever had in any Indian restaurant ever and I love the whole experience if you recommended Jim carner I want to thank you personally thank you very very much if you've been here please tell me what you think if you can like And subscribe to the channel you know I always appreciate that and until next time very lucky person and I recognize that bye-bye that was a brilliant recommendation w
#       Question: is the topic of Indian food discussed in this video? if yes then what was discussed<end_of_turn>
# <start_of_turn>model
# Yes, the topic of Indian food is discussed in the video.
#
# The video reviews a restaurant called Jim Carner, which is considered one of the most expensive and best Indian restaurants in the world. The reviewer discusses the food, describing it as "truly incredible" and "levels above any Indian restaurant I ever been in my life." They highlight specific dishes like the butter masala, prawn curry, and rice pudding, and express their overall satisfaction with the quality and experience.

# %% [markdown]
# ## Building a Chain

# %%
from langchain_core.runnables import RunnableParallel, RunnablePassthrough, RunnableLambda
from langchain_core.output_parsers import StrOutputParser

# %%
def format_docs(retrieved_docs):
  context_text = "\n\n".join(doc.page_content for doc in retrieved_docs)
  return context_text

# %%
parallel_chain = RunnableParallel({
    'context': retriever | RunnableLambda(format_docs),
    'question': RunnablePassthrough()
})

# %%
parallel_chain.invoke('what is Jim Carner?')
# Out:
# {'context': "but that's an experience an experience that if you get the opportunity definitely definitely give it a go certainly at the high end I'm not silly it's really at the high end what marks I'm going to give it loads of you recommended fantastic recommendation it's quality that's the thing that's the standout quality in every aspect every aspect I'm going to give it a 10 out of 10 I've got to give it a 10 out of 10 because each dish that I had there was amongst the best if not the best I've ever had in any Indian restaurant ever and I love the whole experience if you recommended Jim carner I want to thank you personally thank you very very much if you've been here please tell me what you think if you can like And subscribe to the channel you know I always appreciate that and until next time very lucky person and I recognize that bye-bye that was a brilliant recommendation w\n\nJim carner one of the most expensive and one of the best Indian restaurants in the world I can confirm both I love the inside I love the service I like the ambience everything on there was top draw the food wow wow wow wow seriously that food was truly incredible every mouthful every every aspect of it you put it in it had the flavor oh it it was brilliant cameraman he loved it as well so both of us thought that was great onto the bill starter 12250 uh that butter masala £32 the prawn Curry £ 33b Bread Basket 12250 uh the rice £7 and the dessert uh £10 service charge in there uh 15% 12 £ 3£ 123 that's mindblowing In fairness I did order a lot there there enough for two people but that's still an awful lot of money but then again I am looking at quality would I come here all the time you know would I come here all the time no no there's no chance but would is it somewhere you would go for that really special occasion yeah enough food for two people you got to remember that the other\n\nI'm going to go to go cuz if that's what it's all about yeah you taste Tamarind in there and I understand hello there I hope you enjing your lunch I can tell you this is absolutely fabulous thank you so the chef has just come out to say hello here I got to say this is some incredible cooking so thank you very very much Chef thank you thank you he's going around to the tables just making sure everything's good good what a touch that is a fantastic touch just for the chef to come out so as I said one of Rick Stein's U most favorite dishes but I'm not taking any notice of Rick at the moment because me and him are not mates I'm I'm not sending him a Christmas card that's for sure but I want to try it with this naan with coriander in it let's just see have I made a good have I made a good call or good choice or should I've actually gone with just a plane I definitely made a good call getting the king pra Curry there's no doubts about that if you take a look there's so much fresh coriander\n\nit is truly wonderful to see you where are we we're in central London we've come to Mayfair now we are going to a very very special Indian restaurant I went to verish Swami now it's got one Michelin star and loads of you turned around and said Gary there's a better one I was thinking wow there can't be a better one is there gave me a recommendation what is it Jim Cara now it specializes in Northern Indian food and it hasn't got one it's got two to michelan Stars so it's got to be seriously up there you asked me to go here quite a while ago it's Tak me ages to get a booking 3 months waiting list so if you're ever interested in coming here you're going to have to be a bit patient can't wait for it as always got to be careful here let's give it a go kind it has to be very patient the road is suddenly become padilly circus not Mayfair I won't pass go and I won't collect 200 come on look at the menu outside it's certainly not for the Fain hearted I'm going to give you one simple example",
#  'question': 'what is Jim Carner?'}

# %%
parser = StrOutputParser()

# %%
main_chain = parallel_chain | prompt | llm | parser

# %%
main_chain.invoke('Can you summarize the video')
# Out:
# g:\coding\GenAI\venv\Lib\site-packages\transformers\generation\configuration_utils.py:631: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.5` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# '\n      You are a helpful assistant.\n      Answer ONLY from the provided transcript context.\n      If the context is insufficient, just say you don\'t know.\n\n      this is their signature so this is the one everyone goes mad about I\'m going to say the obious is there it\'s buttery it\'s creamy but it has a little little bit of heat a little bit of kick but I\'ve um wow I don\'t know how they make that in that kitchen with that sauce no I can\'t judge it on one so let\'s pick it up let\'s have a bit of chicken on the plate a bit of chicken GES let\'s put that there lots of this sauce this can\'t got to waste on there I want to try that with some of the rice get that there let\'s try try it with just a little bit of rice so give myself in a bit of a kafuffle here it\'s cut into the chicken to say that chicken is tender pulls away his understatement it\'s just come on let\'s get with it in there in there that\'s chicken thigh and what I like the chicken thigh that has got so much flavor so again you have the lights the chicken breast and again that\'s very tasty but the thigh is where all the flavor in a chicken is the meat itself the chicken is super tender that\n\nand creating a big hole in the bottom I can\'t let it go to waste so this one go down so and then I\'ll do the last one with lots of spice even though I put loads of spice in there that\'s not the overriding flavor doesn\'t kill everything although my mouth is tingling away as a starter one is a bit of theater but two is the flavor the flavors are incredible and that is coming from these chickpeas and The Tamarind that\'s the overriding flavor and that is a nice little bit of heat to go on top as a starter that\'s incredible that has really got me excited and yeah what can I say the only thing I can say is I\'m going to finish enjoy the other thing about it as well it\'s quite a light starter so that really helps so again with um Curry it can be a little bit too heavy but this well very very long ping pong balls edible ping pong balls okay I shall see you very soon great starter [Music] [Music] here we go I\'m actually really excited this my prawn going Curry oh wow wow wow the aroma wow wow\n\nlike a bite in one oh my god bang no other word for it that was an explosion of flavor so you have the chickpea then you have some spices in there but the overriding flavor to start with is tamarind I\'m getting excited I\'m moving this over then this guy comes into play and that gives you a real kick so it\'s balancing the flavors so you get this flavor first and then when you actually having it all going around the mouth it\'s just suddenly a major explosion of flavors I\'ve never I\'ve never experienced that before seriously I\'m just I\'m like forget it I\'ve got to go in again don\'t ruin this Gary just cuz you\'re excited once again sorry this going to be on repeat for a little bit but this time a little bit more heat so put you in there oh see see Gary has to ruin it by getting too excited and creating a big hole in the bottom I can\'t let it go to waste so this one go down so and then I\'ll do the last one with lots of spice even though I put loads of spice in there that\'s not the\n\nbut that\'s an experience an experience that if you get the opportunity definitely definitely give it a go certainly at the high end I\'m not silly it\'s really at the high end what marks I\'m going to give it loads of you recommended fantastic recommendation it\'s quality that\'s the thing that\'s the standout quality in every aspect every aspect I\'m going to give it a 10 out of 10 I\'ve got to give it a 10 out of 10 because each dish that I had there was amongst the best if not the best I\'ve ever had in any Indian restaurant ever and I love the whole experience if you recommended Jim carner I want to thank you personally thank you very very much if you\'ve been here please tell me what you think if you can like And subscribe to the channel you know I always appreciate that and un ...
